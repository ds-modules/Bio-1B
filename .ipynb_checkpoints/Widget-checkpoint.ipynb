# %%
import widget1
import widget2

# %% [markdown]
# # Widget 1: Experiments 1 and 2

# %%
widget1.show_widget()

# %% [markdown]
# # Widget 2: Experiment 3

# %%
widget2.show_widget()

# %% [markdown]
# Notebook developed by: Andy Sheu
#
# Data Science Modules: http://data.berkeley.edu/education/modules
